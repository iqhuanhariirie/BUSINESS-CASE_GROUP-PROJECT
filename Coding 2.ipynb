# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cvxpy as cp

# %%
# For data preprocess import
import re
import matplotlib.pyplot as plt
import seaborn as sns
import string
import nltk

# %%
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from string import punctuation
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import contractions

# %%
import nltk
nltk.download('punkt')
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # DATA IMPORT

# %%
import pandas as pd

tweets = pd.read_csv(r'F:\Uni Stuff\BUSINESS CASE_GROUP PROJECT\Dataset _tiktokshop.csv' )
print(tweets)
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.620108e+18  Mon Jan 30 17:15:00 +0000 2023               0
# 1            1.620054e+18  Mon Jan 30 13:39:03 +0000 2023               0
# 2            1.620145e+18  Mon Jan 30 19:41:18 +0000 2023               0
# 3            1.620023e+18  Mon Jan 30 11:37:49 +0000 2023               1
# 4            1.619775e+18  Sun Jan 29 19:10:02 +0000 2023               0
# ...                   ...                             ...             ...
# 998          1.740786e+18  Fri Dec 29 17:24:33 +0000 2023              15
# 999          1.740786e+18  Fri Dec 29 17:24:19 +0000 2023               7
# 1000         1.740786e+18  Fri Dec 29 17:23:36 +0000 2023             114
# 1001         1.740784e+18  Fri Dec 29 17:17:44 +0000 2023              32
# 1002         1.740776e+18  Fri Dec 29 17:13:18 +0000 2023               0
#
#                                               full_text        id_str  \
# 0     lmaoooo don't buy perfumes off tiktok shop the...  1.620108e+18
# 1     My SHOP pay app full of orders I be ordering a...  1.620054e+18
# 2         Someone take tiktok shop away from me please   1.620145e+18
# 3     Why do TikTok Shop succeed but Instagram Shop ...  1.620023e+18
# 4     TikTok has changed the way products are market...  1.619775e+18
# ...                                                 ...           ...
# 998   Should I come out with a guide to help the com...  1.740786e+18
# 999   tf tiktok shop recommending me dawg https://t....  1.740786e+18
# 1000  I made a brand $89k the month of December. I v...  1.740786e+18
# 1001  The best part about TikTok Shop is the chicken...  1.740784e+18
# 1002  @slowyourprose Yo wtf I need to shop through T...  1.740783e+18
#
#                                             image_url in_reply_to_screen_name  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# ...                                               ...                     ...
# 998                                               NaN          contentbyjaida
# 999   https://pbs.twimg.com/media/GCiDfGiXIAAMpWk.jpg                     NaN
# 1000  https://pbs.twimg.com/media/GCiDUr9XwAAiccJ.jpg                     NaN
# 1001                                              NaN                     NaN
# 1002                                              NaN           slowyourprose
#
#      lang                   location  quote_count  reply_count  retweet_count  \
# 0      en                        NaN            0            1              0
# 1      en                  Tampa, FL            0            0              0
# 2      en             Swansea, Wales            0            0              0
# 3      en                  Kabupaten            0            2              0
# 4      en  Ready to learn more? ðŸ‘‰            0            0              0
# ...   ...                        ...          ...          ...            ...
# 998    en         Virginia Beach, VA            0            4              0
# 999    en                        NaN            0            1              0
# 1000   en         Virginia Beach, VA            1           33              4
# 1001   en                        NaN            0            1              2
# 1002   en  Toronto, Ontario ðŸ‡¨ðŸ‡¦            0            1              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/p1scesprincess/status/1620108330...  1.476020e+18
# 1     https://x.com/TheGeWayy/status/162005398468494...  2.684152e+08
# 2     https://x.com/chelsey_thomas/status/1620145146...  2.458891e+07
# 3     https://x.com/wooper_dome/status/1620023472847...  1.771727e+08
# 4     https://x.com/jackie_startok/status/1619774888...  1.430244e+18
# ...                                                 ...           ...
# 998   https://x.com/contentbyjaida/status/1740785890...  1.373135e+18
# 999   https://x.com/MosudaMania/status/1740785832334...  1.044586e+18
# 1000  https://x.com/contentbyjaida/status/1740785652...  1.373135e+18
# 1001  https://x.com/BowTiedOpossum/status/1740784176...  1.393004e+18
# 1002   https://x.com/kvncnls/status/1740783061535789449  1.287882e+18
#
#             username
# 0     p1scesprincess
# 1          TheGeWayy
# 2     chelsey_thomas
# 3        wooper_dome
# 4     jackie_startok
# ...              ...
# 998   contentbyjaida
# 999      MosudaMania
# 1000  contentbyjaida
# 1001  BowTiedOpossum
# 1002         kvncnls
#
# [1003 rows x 15 columns]

# %%
tweets
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.620108e+18  Mon Jan 30 17:15:00 +0000 2023               0
# 1            1.620054e+18  Mon Jan 30 13:39:03 +0000 2023               0
# 2            1.620145e+18  Mon Jan 30 19:41:18 +0000 2023               0
# 3            1.620023e+18  Mon Jan 30 11:37:49 +0000 2023               1
# 4            1.619775e+18  Sun Jan 29 19:10:02 +0000 2023               0
# ...                   ...                             ...             ...
# 998          1.740786e+18  Fri Dec 29 17:24:33 +0000 2023              15
# 999          1.740786e+18  Fri Dec 29 17:24:19 +0000 2023               7
# 1000         1.740786e+18  Fri Dec 29 17:23:36 +0000 2023             114
# 1001         1.740784e+18  Fri Dec 29 17:17:44 +0000 2023              32
# 1002         1.740776e+18  Fri Dec 29 17:13:18 +0000 2023               0
#
#                                               full_text        id_str  \
# 0     lmaoooo don't buy perfumes off tiktok shop the...  1.620108e+18
# 1     My SHOP pay app full of orders I be ordering a...  1.620054e+18
# 2         Someone take tiktok shop away from me please   1.620145e+18
# 3     Why do TikTok Shop succeed but Instagram Shop ...  1.620023e+18
# 4     TikTok has changed the way products are market...  1.619775e+18
# ...                                                 ...           ...
# 998   Should I come out with a guide to help the com...  1.740786e+18
# 999   tf tiktok shop recommending me dawg https://t....  1.740786e+18
# 1000  I made a brand $89k the month of December. I v...  1.740786e+18
# 1001  The best part about TikTok Shop is the chicken...  1.740784e+18
# 1002  @slowyourprose Yo wtf I need to shop through T...  1.740783e+18
#
#                                             image_url in_reply_to_screen_name  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# ...                                               ...                     ...
# 998                                               NaN          contentbyjaida
# 999   https://pbs.twimg.com/media/GCiDfGiXIAAMpWk.jpg                     NaN
# 1000  https://pbs.twimg.com/media/GCiDUr9XwAAiccJ.jpg                     NaN
# 1001                                              NaN                     NaN
# 1002                                              NaN           slowyourprose
#
#      lang                   location  quote_count  reply_count  retweet_count  \
# 0      en                        NaN            0            1              0
# 1      en                  Tampa, FL            0            0              0
# 2      en             Swansea, Wales            0            0              0
# 3      en                  Kabupaten            0            2              0
# 4      en  Ready to learn more? ðŸ‘‰            0            0              0
# ...   ...                        ...          ...          ...            ...
# 998    en         Virginia Beach, VA            0            4              0
# 999    en                        NaN            0            1              0
# 1000   en         Virginia Beach, VA            1           33              4
# 1001   en                        NaN            0            1              2
# 1002   en  Toronto, Ontario ðŸ‡¨ðŸ‡¦            0            1              0
#
#                                               tweet_url   user_id_str  \
# 0     https://x.com/p1scesprincess/status/1620108330...  1.476020e+18
# 1     https://x.com/TheGeWayy/status/162005398468494...  2.684152e+08
# 2     https://x.com/chelsey_thomas/status/1620145146...  2.458891e+07
# 3     https://x.com/wooper_dome/status/1620023472847...  1.771727e+08
# 4     https://x.com/jackie_startok/status/1619774888...  1.430244e+18
# ...                                                 ...           ...
# 998   https://x.com/contentbyjaida/status/1740785890...  1.373135e+18
# 999   https://x.com/MosudaMania/status/1740785832334...  1.044586e+18
# 1000  https://x.com/contentbyjaida/status/1740785652...  1.373135e+18
# 1001  https://x.com/BowTiedOpossum/status/1740784176...  1.393004e+18
# 1002   https://x.com/kvncnls/status/1740783061535789449  1.287882e+18
#
#             username
# 0     p1scesprincess
# 1          TheGeWayy
# 2     chelsey_thomas
# 3        wooper_dome
# 4     jackie_startok
# ...              ...
# 998   contentbyjaida
# 999      MosudaMania
# 1000  contentbyjaida
# 1001  BowTiedOpossum
# 1002         kvncnls
#
# [1003 rows x 15 columns]

# %%
tweets.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0         1.620108e+18  Mon Jan 30 17:15:00 +0000 2023               0
# 1         1.620054e+18  Mon Jan 30 13:39:03 +0000 2023               0
# 2         1.620145e+18  Mon Jan 30 19:41:18 +0000 2023               0
# 3         1.620023e+18  Mon Jan 30 11:37:49 +0000 2023               1
# 4         1.619775e+18  Sun Jan 29 19:10:02 +0000 2023               0
#
#                                            full_text        id_str image_url  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...  1.620108e+18       NaN
# 1  My SHOP pay app full of orders I be ordering a...  1.620054e+18       NaN
# 2      Someone take tiktok shop away from me please   1.620145e+18       NaN
# 3  Why do TikTok Shop succeed but Instagram Shop ...  1.620023e+18       NaN
# 4  TikTok has changed the way products are market...  1.619775e+18       NaN
#
#   in_reply_to_screen_name lang                   location  quote_count  \
# 0                     NaN   en                        NaN            0
# 1                     NaN   en                  Tampa, FL            0
# 2                     NaN   en             Swansea, Wales            0
# 3                     NaN   en                  Kabupaten            0
# 4                     NaN   en  Ready to learn more? ðŸ‘‰            0
#
#    reply_count  retweet_count  \
# 0            1              0
# 1            0              0
# 2            0              0
# 3            2              0
# 4            0              0
#
#                                            tweet_url   user_id_str  \
# 0  https://x.com/p1scesprincess/status/1620108330...  1.476020e+18
# 1  https://x.com/TheGeWayy/status/162005398468494...  2.684152e+08
# 2  https://x.com/chelsey_thomas/status/1620145146...  2.458891e+07
# 3  https://x.com/wooper_dome/status/1620023472847...  1.771727e+08
# 4  https://x.com/jackie_startok/status/1619774888...  1.430244e+18
#
#          username
# 0  p1scesprincess
# 1       TheGeWayy
# 2  chelsey_thomas
# 3     wooper_dome
# 4  jackie_startok

# %%
tweets_df = tweets[['full_text']]
tweets_df.head()
# Out:
#                                            full_text
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...

# %%
tweets_df.shape
# Out:
# (1003, 1)

# %% [markdown]
# # DATA PREPROCESSING

# %%
tweets.drop_duplicates(inplace = True, subset="full_text")
tweets.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 998     False
# 999     False
# 1000    False
# 1001    False
# 1002    False
# Length: 997, dtype: bool

# %%
tweets_df
# Out:
#                                               full_text
# 0     lmaoooo don't buy perfumes off tiktok shop the...
# 1     My SHOP pay app full of orders I be ordering a...
# 2         Someone take tiktok shop away from me please
# 3     Why do TikTok Shop succeed but Instagram Shop ...
# 4     TikTok has changed the way products are market...
# ...                                                 ...
# 998   Should I come out with a guide to help the com...
# 999   tf tiktok shop recommending me dawg https://t....
# 1000  I made a brand $89k the month of December. I v...
# 1001  The best part about TikTok Shop is the chicken...
# 1002  @slowyourprose Yo wtf I need to shop through T...
#
# [1003 rows x 1 columns]

# %%
#To view the information of data
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  1003 non-null   object
# dtypes: object(1)
# memory usage: 8.0+ KB

# %%
#To create dataframe
cleaned = tweets_df[["full_text"]]

#Rearrange the index
cleaned_df = cleaned.reset_index(drop = True)
cleaned_df
# Out:
#                                               full_text
# 0     lmaoooo don't buy perfumes off tiktok shop the...
# 1     My SHOP pay app full of orders I be ordering a...
# 2         Someone take tiktok shop away from me please
# 3     Why do TikTok Shop succeed but Instagram Shop ...
# 4     TikTok has changed the way products are market...
# ...                                                 ...
# 998   Should I come out with a guide to help the com...
# 999   tf tiktok shop recommending me dawg https://t....
# 1000  I made a brand $89k the month of December. I v...
# 1001  The best part about TikTok Shop is the chicken...
# 1002  @slowyourprose Yo wtf I need to shop through T...
#
# [1003 rows x 1 columns]

# %%
#To remove NaN
cleaned_df = cleaned_df.dropna()

#To view the data after removing NaN
cleaned_df
# Out:
#                                               full_text
# 0     lmaoooo don't buy perfumes off tiktok shop the...
# 1     My SHOP pay app full of orders I be ordering a...
# 2         Someone take tiktok shop away from me please
# 3     Why do TikTok Shop succeed but Instagram Shop ...
# 4     TikTok has changed the way products are market...
# ...                                                 ...
# 998   Should I come out with a guide to help the com...
# 999   tf tiktok shop recommending me dawg https://t....
# 1000  I made a brand $89k the month of December. I v...
# 1001  The best part about TikTok Shop is the chicken...
# 1002  @slowyourprose Yo wtf I need to shop through T...
#
# [1003 rows x 1 columns]

# %%
#Lowercase coversion
cleaned_df['lowercase'] = cleaned_df.full_text.str.lower()
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...

# %%
#to convert the datatype to string
cleaned_df.full_text = cleaned_df.full_text.astype(str)

# %%
#Remove URL link
import re
cleaned_df['remove_link'] = cleaned_df.lowercase.apply(lambda x: re.sub(r'https?:\/\/\S+', '',x))
cleaned_df.lowercase.apply(lambda x: re.sub(r"www\.[a-z]?\.?(com)+|[a-z]+\.(com)", '', x))
                                                                                                                                              
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...

# %%
#remove twitter handles (mention)
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
        return input_txt

# %%
#remove twitter handles (user)
cleaned_df['mention'] = np.vectorize(remove_pattern)(cleaned_df['remove_link'], "@[\w]*")

cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None

# %%
import string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
cleaned_df['punctuation'] = cleaned_df['remove_link'].apply(lambda x: ''.join([char for char in x if char not in string.punctuation]))

print(cleaned_df)
# Out:
#                                               full_text  \
# 0     lmaoooo don't buy perfumes off tiktok shop the...
# 1     My SHOP pay app full of orders I be ordering a...
# 2         Someone take tiktok shop away from me please
# 3     Why do TikTok Shop succeed but Instagram Shop ...
# 4     TikTok has changed the way products are market...
# ...                                                 ...
# 998   Should I come out with a guide to help the com...
# 999   tf tiktok shop recommending me dawg https://t....
# 1000  I made a brand $89k the month of December. I v...
# 1001  The best part about TikTok Shop is the chicken...
# 1002  @slowyourprose Yo wtf I need to shop through T...
#
#                                               lowercase  \
# 0     lmaoooo don't buy perfumes off tiktok shop the...
# 1     my shop pay app full of orders i be ordering a...
# 2         someone take tiktok shop away from me please
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# ...                                                 ...
# 998   should i come out with a guide to help the com...
# 999   tf tiktok shop recommending me dawg https://t....
# 1000  i made a brand $89k the month of december. i v...
# 1001  the best part about tiktok shop is the chicken...
# 1002  @slowyourprose yo wtf i need to shop through t...
#
#                                             remove_link  \
# 0     lmaoooo don't buy perfumes off tiktok shop the...
# 1     my shop pay app full of orders i be ordering a...
# 2         someone take tiktok shop away from me please
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# ...                                                 ...
# 998   should i come out with a guide to help the com...
# 999                tf tiktok shop recommending me dawg
# 1000  i made a brand $89k the month of december. i v...
# 1001  the best part about tiktok shop is the chicken...
# 1002  @slowyourprose yo wtf i need to shop through t...
#
#                                      mention  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 998                                     None
# 999                                     None
# 1000                                    None
# 1001                                    None
# 1002   yo wtf i need to shop through tiktok
#
#                                             punctuation
# 0     lmaoooo dont buy perfumes off tiktok shop thes...
# 1     my shop pay app full of orders i be ordering a...
# 2         someone take tiktok shop away from me please
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# ...                                                 ...
# 998   should i come out with a guide to help the com...
# 999                tf tiktok shop recommending me dawg
# 1000  i made a brand 89k the month of december i ve ...
# 1001  the best part about tiktok shop is the chicken...
# 1002  slowyourprose yo wtf i need to shop through ti...
#
# [1003 rows x 5 columns]

# %%
def clean_text(full_text):
    return re.sub(r'[^\w\s]', '', full_text)

# %%
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation
# 0  lmaoooo dont buy perfumes off tiktok shop thes...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...

# %%
cleaned_df['remove_link'].apply(lambda x: clean_text(x))
# Out:
# 0       lmaoooo dont buy perfumes off tiktok shop thes...
# 1       my shop pay app full of orders i be ordering a...
# 2           someone take tiktok shop away from me please
# 3       why do tiktok shop succeed but instagram shop ...
# 4       tiktok has changed the way products are market...
#                               ...
# 998     should i come out with a guide to help the com...
# 999                  tf tiktok shop recommending me dawg
# 1000    i made a brand 89k the month of december i ve ...
# 1001    the best part about tiktok shop is the chicken...
# 1002    slowyourprose yo wtf i need to shop through ti...
# Name: remove_link, Length: 1003, dtype: object

# %%
#Remove punctuation
cleaned_df['punctuation'] = cleaned_df.remove_link.apply(lambda x: re.sub(r"[^a-z\s\(\-:\)\\\/\];='#]", '', x))

cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...

# %%
cleaned_df['expand_word'] = cleaned_df['punctuation'].apply(lambda x: [contractions.fix(word) for word in x.split()])

# %%
cleaned_df['expand_word'] = [' '.join(map(str, l)) for l in cleaned_df['expand_word']]

cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...

# %%
#Remove #
cleaned_df['hashtag']= cleaned_df.expand_word.apply(lambda x: re.sub("#[A-Za-z0-9_]+","", x))

cleaned_df.head(3)
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
#
#                                              hashtag
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please

# %%
#remove short word that has length word 2 or less
cleaned_df['remove_short'] = cleaned_df['hashtag'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>2]))

cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...

# %%
#tokenization
import nltk
nltk.download('punkt_tab')

cleaned_df['tokenized'] = cleaned_df['remove_short'].apply(word_tokenize)
cleaned_df.head()
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...

# %%
#Stop word library
nltk.download("stopwords")
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Stopword removal

import nltk
from nltk.corpus import stopwords
set(stopwords.words('english'))

#set of stop words
stop_words = set(stopwords.words('english'))

cleaned_df['stopwords_removed'] = cleaned_df.tokenized.apply(lambda x: [word for word in x if word not in stop_words])

# %%
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized  \
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...
#
#                                    stopwords_removed
# 0  [lmaoooo, buy, perfumes, tiktok, shop, people,...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, faile...
# 4  [tiktok, changed, way, products, marketed, for...

# %%
#pos tag to label the type of word
import nltk
nltk.download('averaged_perceptron_tagger_eng')

cleaned_df['pos_tags'] = cleaned_df['stopwords_removed'].apply(nltk.tag.pos_tag)
cleaned_df.head()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized  \
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...
#
#                                    stopwords_removed  \
# 0  [lmaoooo, buy, perfumes, tiktok, shop, people,...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, faile...
# 4  [tiktok, changed, way, products, marketed, for...
#
#                                             pos_tags
# 0  [(lmaoooo, JJ), (buy, NN), (perfumes, NNS), (t...
# 1  [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 2  [(someone, NN), (take, VB), (tiktok, NN), (sho...
# 3  [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 4  [(tiktok, NNS), (changed, VBD), (way, NN), (pr...

# %%
#To convert pos tag to word net to use lemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
cleaned_df['wordnet_pos'] = cleaned_df['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

# %%
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized  \
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...
#
#                                    stopwords_removed  \
# 0  [lmaoooo, buy, perfumes, tiktok, shop, people,...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, faile...
# 4  [tiktok, changed, way, products, marketed, for...
#
#                                             pos_tags  \
# 0  [(lmaoooo, JJ), (buy, NN), (perfumes, NNS), (t...
# 1  [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 2  [(someone, NN), (take, VB), (tiktok, NN), (sho...
# 3  [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 4  [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
#
#                                          wordnet_pos
# 0  [(lmaoooo, a), (buy, n), (perfumes, n), (tikto...
# 1  [(shop, n), (pay, n), (app, v), (full, a), (or...
# 2  [(someone, n), (take, v), (tiktok, n), (shop, ...
# 3  [(tiktok, n), (shop, n), (succeed, v), (instag...
# 4  [(tiktok, n), (changed, v), (way, n), (product...

# %%
#Lemmatizer
wnl = WordNetLemmatizer()
cleaned_df['lemmatized'] = cleaned_df['wordnet_pos'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized  \
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...
#
#                                    stopwords_removed  \
# 0  [lmaoooo, buy, perfumes, tiktok, shop, people,...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, faile...
# 4  [tiktok, changed, way, products, marketed, for...
#
#                                             pos_tags  \
# 0  [(lmaoooo, JJ), (buy, NN), (perfumes, NNS), (t...
# 1  [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 2  [(someone, NN), (take, VB), (tiktok, NN), (sho...
# 3  [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 4  [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
#
#                                          wordnet_pos  \
# 0  [(lmaoooo, a), (buy, n), (perfumes, n), (tikto...
# 1  [(shop, n), (pay, n), (app, v), (full, a), (or...
# 2  [(someone, n), (take, v), (tiktok, n), (shop, ...
# 3  [(tiktok, n), (shop, n), (succeed, v), (instag...
# 4  [(tiktok, n), (changed, v), (way, n), (product...
#
#                                           lemmatized
# 0  [lmaoooo, buy, perfume, tiktok, shop, people, ...
# 1  [shop, pay, app, full, order, order, anything,...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, fail,...
# 4  [tiktok, change, way, product, market, forever...

# %%
#Saving dataframe in csv
cleaned_df.to_csv('Preprocessed_Data')
# tweets_df.to_excel("preprocessed_data.xlsx", index=False)

# %% [markdown]
# # Label Using Text Blob

# %%
#labelling library

import string
import nltk
import plotly.express as px
from nltk.sentiment.util import *

# %%
from wordcloud import WordCloud
import os
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from textblob import TextBlob
from nltk import tokenize

# %%
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized  \
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...
#
#                                    stopwords_removed  \
# 0  [lmaoooo, buy, perfumes, tiktok, shop, people,...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, faile...
# 4  [tiktok, changed, way, products, marketed, for...
#
#                                             pos_tags  \
# 0  [(lmaoooo, JJ), (buy, NN), (perfumes, NNS), (t...
# 1  [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 2  [(someone, NN), (take, VB), (tiktok, NN), (sho...
# 3  [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 4  [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
#
#                                          wordnet_pos  \
# 0  [(lmaoooo, a), (buy, n), (perfumes, n), (tikto...
# 1  [(shop, n), (pay, n), (app, v), (full, a), (or...
# 2  [(someone, n), (take, v), (tiktok, n), (shop, ...
# 3  [(tiktok, n), (shop, n), (succeed, v), (instag...
# 4  [(tiktok, n), (changed, v), (way, n), (product...
#
#                                           lemmatized
# 0  [lmaoooo, buy, perfume, tiktok, shop, people, ...
# 1  [shop, pay, app, full, order, order, anything,...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, fail,...
# 4  [tiktok, change, way, product, market, forever...

# %%
#using polarity
from textblob import TextBlob

# Ensure the 'lemmatized' column is of type string
cleaned_df["lemmatized"] = cleaned_df["lemmatized"].astype("str")
cleaned_df['label'] = ''  # Initialize the 'label' column

# Iterate over the rows of the 'lemmatized' column using items()
for i, x in cleaned_df['lemmatized'].items():
    label = TextBlob(x)
    cleaned_df.at[i, 'label'] = label.sentiment.polarity  # Use .at to set the value
    print("Index: ", i, "label", label.sentiment.polarity)
# Out:
# Index:  0 label 0.0
# Index:  1 label 0.07499999999999998
# Index:  2 label 0.0
# Index:  3 label -0.75
# Index:  4 label 0.4166666666666667
# Index:  5 label 0.13636363636363635
# Index:  6 label 0.0
# Index:  7 label 0.0
# Index:  8 label 0.24444444444444446
# Index:  9 label 0.8
# Index:  10 label 0.0
# Index:  11 label 0.0
# Index:  12 label 0.0
# Index:  13 label 0.1340909090909091
# Index:  14 label 0.0
# Index:  15 label 0.03333333333333333
# Index:  16 label 0.03434343434343434
# Index:  17 label 0.35
# Index:  18 label 0.75
# Index:  19 label 0.2857142857142857
# Index:  20 label 0.0
# Index:  21 label 0.125
# Index:  22 label 0.4333333333333333
# Index:  23 label -0.5
# Index:  24 label 0.0
# Index:  25 label 0.35
# Index:  26 label 0.0
# Index:  27 label 0.0
# Index:  28 label 0.0
# Index:  29 label 0.2
# Index:  30 label 0.0
# Index:  31 label 0.0
# Index:  32 label -0.6999999999999998
# Index:  33 label -0.18333333333333335
# Index:  34 label 0.0
# Index:  35 label 0.0
# Index:  36 label 0.0
# Index:  37 label 0.04545454545454545
# Index:  38 label 0.0
# Index:  39 label 0.024999999999999994
# Index:  40 label 0.8
# Index:  41 label 0.5
# Index:  42 label -0.20000000000000004
# Index:  43 label 0.2
# Index:  44 label -0.5
# Index:  45 label -0.8
# Index:  46 label 0.0
# Index:  47 label 0.4
# Index:  48 label 0.0
# Index:  49 label 0.0
# Index:  50 label 0.0
# Index:  51 label 0.5
# Index:  52 label -0.4
# Index:  53 label -0.2
# Index:  54 label 0.0
# Index:  55 label -0.08333333333333333
# Index:  56 label -0.14999999999999997
# Index:  57 label 0.29523809523809524
# Index:  58 label -0.4
# Index:  905 label 0.0
# Index:  906 label 0.0
# Index:  907 label 0.0
# Index:  908 label 0.0
# Index:  909 label 0.04545454545454545
# Index:  910 label 0.0
# Index:  911 label 0.225
# Index:  912 label -0.16666666666666666
# Index:  913 label 0.25
# Index:  914 label -0.2
# Index:  915 label 0.0
# Index:  916 label -0.1
# Index:  917 label 0.0
# Index:  918 label 0.0
# Index:  919 label 0.16428571428571426
# Index:  920 label 0.0
# Index:  921 label 0.19999999999999998
# Index:  922 label 0.0
# Index:  923 label 0.0
# Index:  924 label 0.0
# Index:  925 label 0.0
# Index:  926 label 0.0
# Index:  927 label -0.4
# Index:  928 label 0.43333333333333335
# Index:  929 label 0.175
# Index:  930 label -0.25
# Index:  931 label 0.8
# Index:  932 label 0.0
# Index:  933 label -0.6999999999999998
# Index:  934 label 0.0
# Index:  935 label 0.0
# Index:  936 label 0.51
# Index:  937 label 0.2
# Index:  938 label 0.25
# Index:  939 label -0.5
# Index:  940 label 0.0
# Index:  941 label 0.0
# Index:  942 label 0.3333333333333333
# Index:  943 label 0.0
# Index:  944 label -0.25
# Index:  945 label -0.45555555555555555
# Index:  946 label 1.0
# Index:  947 label 0.0
# Index:  948 label 0.39999999999999997
# Index:  949 label 0.2333333333333333
# Index:  950 label 0.2625
# Index:  951 label 0.04166666666666667
# Index:  952 label -0.2
# Index:  953 label 0.4
# Index:  954 label 0.7
# Index:  955 label 0.13636363636363635
# Index:  956 label 0.2681818181818182
# Index:  957 label 0.15000000000000002
# Index:  958 label 0.75
# Index:  959 label 0.0
# Index:  960 label 0.09318181818181817
# Index:  961 label 0.0
# Index:  962 label 0.0
# Index:  963 label 0.7
# Index:  964 label 0.0
# Index:  965 label 0.16666666666666666
# Index:  966 label 0.0
# Index:  967 label -0.16249999999999992
# Index:  968 label 0.32857142857142857
# Index:  969 label 0.2590909090909091
# Index:  970 label 0.0
# Index:  971 label -0.1
# Index:  972 label 0.5
# Index:  973 label 0.2
# Index:  974 label 0.0
# Index:  975 label 0.0
# Index:  976 label 0.125
# Index:  977 label 0.7
# Index:  978 label 0.2
# Index:  979 label 0.0
# Index:  980 label -0.03749999999999995
# Index:  981 label 0.0
# Index:  982 label 0.0
# Index:  983 label -0.2916666666666667
# Index:  984 label 0.0
# Index:  985 label 0.0
# Index:  986 label 0.375
# Index:  987 label 0.0
# Index:  988 label 0.25
# Index:  989 label 0.0
# Index:  990 label 0.0
# Index:  991 label 0.4
# Index:  992 label 0.05000000000000002
# Index:  993 label 0.2777777777777778
# Index:  994 label -0.06666666666666667
# Index:  995 label 0.0
# Index:  996 label 0.8
# Index:  997 label 0.0
# Index:  998 label 0.0
# Index:  999 label 0.0
# Index:  1000 label 0.1
# Index:  1001 label 0.16666666666666666
# Index:  1002 label -0.5

# %%
cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized  \
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...
#
#                                    stopwords_removed  \
# 0  [lmaoooo, buy, perfumes, tiktok, shop, people,...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, faile...
# 4  [tiktok, changed, way, products, marketed, for...
#
#                                             pos_tags  \
# 0  [(lmaoooo, JJ), (buy, NN), (perfumes, NNS), (t...
# 1  [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 2  [(someone, NN), (take, VB), (tiktok, NN), (sho...
# 3  [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 4  [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
#
#                                          wordnet_pos  \
# 0  [(lmaoooo, a), (buy, n), (perfumes, n), (tikto...
# 1  [(shop, n), (pay, n), (app, v), (full, a), (or...
# 2  [(someone, n), (take, v), (tiktok, n), (shop, ...
# 3  [(tiktok, n), (shop, n), (succeed, v), (instag...
# 4  [(tiktok, n), (changed, v), (way, n), (product...
#
#                                           lemmatized     label
# 0  ['lmaoooo', 'buy', 'perfume', 'tiktok', 'shop'...       0.0
# 1  ['shop', 'pay', 'app', 'full', 'order', 'order...     0.075
# 2  ['someone', 'take', 'tiktok', 'shop', 'away', ...       0.0
# 3  ['tiktok', 'shop', 'succeed', 'instagram', 'sh...     -0.75
# 4  ['tiktok', 'change', 'way', 'product', 'market...  0.416667

# %%
#to simplify the polarity become positive and negative

def polarity_to_label(x):
    if(x >= -1 and x < 0):
        return 'neg'
    if(x == 0):
        return 'neutral'
    if(x > 0 and x <= 1):
        return 'pos'
cleaned_df.label = cleaned_df.label.apply(polarity_to_label)

cleaned_df.head()
# Out:
#                                            full_text  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  My SHOP pay app full of orders I be ordering a...
# 2      Someone take tiktok shop away from me please
# 3  Why do TikTok Shop succeed but Instagram Shop ...
# 4  TikTok has changed the way products are market...
#
#                                            lowercase  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          remove_link mention  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...    None
# 1  my shop pay app full of orders i be ordering a...    None
# 2      someone take tiktok shop away from me please     None
# 3  why do tiktok shop succeed but instagram shop ...    None
# 4  tiktok has changed the way products are market...    None
#
#                                          punctuation  \
# 0  lmaoooo don't buy perfumes off tiktok shop the...
# 1  my shop pay app full of orders i be ordering a...
# 2      someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                          expand_word  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                              hashtag  \
# 0  lmaoooo do not buy perfumes off tiktok shop th...
# 1  my shop pay app full of orders i be ordering a...
# 2       someone take tiktok shop away from me please
# 3  why do tiktok shop succeed but instagram shop ...
# 4  tiktok has changed the way products are market...
#
#                                         remove_short  \
# 0  lmaoooo not buy perfumes off tiktok shop these...
# 1  shop pay app full orders ordering anything see...
# 2          someone take tiktok shop away from please
# 3  why tiktok shop succeed but instagram shop fai...
# 4  tiktok has changed the way products are market...
#
#                                            tokenized  \
# 0  [lmaoooo, not, buy, perfumes, off, tiktok, sho...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2  [someone, take, tiktok, shop, away, from, please]
# 3  [why, tiktok, shop, succeed, but, instagram, s...
# 4  [tiktok, has, changed, the, way, products, are...
#
#                                    stopwords_removed  \
# 0  [lmaoooo, buy, perfumes, tiktok, shop, people,...
# 1  [shop, pay, app, full, orders, ordering, anyth...
# 2        [someone, take, tiktok, shop, away, please]
# 3  [tiktok, shop, succeed, instagram, shop, faile...
# 4  [tiktok, changed, way, products, marketed, for...
#
#                                             pos_tags  \
# 0  [(lmaoooo, JJ), (buy, NN), (perfumes, NNS), (t...
# 1  [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 2  [(someone, NN), (take, VB), (tiktok, NN), (sho...
# 3  [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 4  [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
#
#                                          wordnet_pos  \
# 0  [(lmaoooo, a), (buy, n), (perfumes, n), (tikto...
# 1  [(shop, n), (pay, n), (app, v), (full, a), (or...
# 2  [(someone, n), (take, v), (tiktok, n), (shop, ...
# 3  [(tiktok, n), (shop, n), (succeed, v), (instag...
# 4  [(tiktok, n), (changed, v), (way, n), (product...
#
#                                           lemmatized    label
# 0  ['lmaoooo', 'buy', 'perfume', 'tiktok', 'shop'...  neutral
# 1  ['shop', 'pay', 'app', 'full', 'order', 'order...      pos
# 2  ['someone', 'take', 'tiktok', 'shop', 'away', ...  neutral
# 3  ['tiktok', 'shop', 'succeed', 'instagram', 'sh...      neg
# 4  ['tiktok', 'change', 'way', 'product', 'market...      pos

# %%
cleaned_df.label.value_counts()
# Out:
# label
# neutral    412
# pos        380
# neg        211
# Name: count, dtype: int64

# %%
#visualise the label

cleaned_df.label.value_counts().plot(kind='bar',title="Sentiment Analysis")
# Out:
# <Axes: title={'center': 'Sentiment Analysis'}, xlabel='label'>

# %%
#removing neutral label since prediction within this project revolve
#with neg and pos only
df = cleaned_df[cleaned_df.label !="neutral"]

df.count()
# Out:
# full_text            591
# lowercase            591
# remove_link          591
# mention              140
# punctuation          591
# expand_word          591
# hashtag              591
# remove_short         591
# tokenized            591
# stopwords_removed    591
# pos_tags             591
# wordnet_pos          591
# lemmatized           591
# label                591
# dtype: int64

# %%
df
# Out:
#                                               full_text  \
# 1     My SHOP pay app full of orders I be ordering a...
# 3     Why do TikTok Shop succeed but Instagram Shop ...
# 4     TikTok has changed the way products are market...
# 5     tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 8     I can t stop buying stuff from tiktok shop I a...
# ...                                                 ...
# 994   So you witches haven t been calling Whitney sm...
# 996                      I stay on that TikTok shop lol
# 1000  I made a brand $89k the month of December. I v...
# 1001  The best part about TikTok Shop is the chicken...
# 1002  @slowyourprose Yo wtf I need to shop through T...
#
#                                               lowercase  \
# 1     my shop pay app full of orders i be ordering a...
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# 5     tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 8     i can t stop buying stuff from tiktok shop i a...
# ...                                                 ...
# 994   so you witches haven t been calling whitney sm...
# 996                      i stay on that tiktok shop lol
# 1000  i made a brand $89k the month of december. i v...
# 1001  the best part about tiktok shop is the chicken...
# 1002  @slowyourprose yo wtf i need to shop through t...
#
#                                             remove_link  \
# 1     my shop pay app full of orders i be ordering a...
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# 5     tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 8     i can t stop buying stuff from tiktok shop i a...
# ...                                                 ...
# 994   so you witches haven t been calling whitney sm...
# 996                      i stay on that tiktok shop lol
# 1000  i made a brand $89k the month of december. i v...
# 1001  the best part about tiktok shop is the chicken...
# 1002  @slowyourprose yo wtf i need to shop through t...
#
#                                      mention  \
# 1                                       None
# 3                                       None
# 4                                       None
# 5                                       None
# 8                                       None
# ...                                      ...
# 994                                     None
# 996                                     None
# 1000                                    None
# 1001                                    None
# 1002   yo wtf i need to shop through tiktok
#
#                                             punctuation  \
# 1     my shop pay app full of orders i be ordering a...
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# 5        tiktok shop is my new shopee app :gt;gt;gt;gt;
# 8     i can t stop buying stuff from tiktok shop i a...
# ...                                                 ...
# 994   so you witches haven t been calling whitney sm...
# 996                      i stay on that tiktok shop lol
# 1000  i made a brand k the month of december i ve en...
# 1001  the best part about tiktok shop is the chicken...
# 1002  slowyourprose yo wtf i need to shop through ti...
#
#                                             expand_word  \
# 1     my shop pay app full of orders i be ordering a...
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# 5        tiktok shop is my new shopee app :gt;gt;gt;gt;
# 8     i can t stop buying stuff from tiktok shop i a...
# ...                                                 ...
# 994   so you witches haven t been calling whitney sm...
# 996                      i stay on that tiktok shop lol
# 1000  i made a brand k the month of december i ve en...
# 1001  the best part about tiktok shop is the chicken...
# 1002  slowyourprose yo wtf i need to shop through ti...
#
#                                                 hashtag  \
# 1     my shop pay app full of orders i be ordering a...
# 3     why do tiktok shop succeed but instagram shop ...
# 4     tiktok has changed the way products are market...
# 5        tiktok shop is my new shopee app :gt;gt;gt;gt;
# 8     i can t stop buying stuff from tiktok shop i a...
# ...                                                 ...
# 994   so you witches haven t been calling whitney sm...
# 996                      i stay on that tiktok shop lol
# 1000  i made a brand k the month of december i ve en...
# 1001  the best part about tiktok shop is the chicken...
# 1002  slowyourprose yo wtf i need to shop through ti...
#
#                                            remove_short  \
# 1     shop pay app full orders ordering anything see...
# 3     why tiktok shop succeed but instagram shop fai...
# 4     tiktok has changed the way products are market...
# 5              tiktok shop new shopee app :gt;gt;gt;gt;
# 8     can stop buying stuff from tiktok shop too eas...
# ...                                                 ...
# 994   you witches haven been calling whitney smug fo...
# 996                           stay that tiktok shop lol
# 1000  made brand the month december ended the month ...
# 1001  the best part about tiktok shop the chickens a...
# 1002         slowyourprose wtf need shop through tiktok
#
#                                               tokenized  \
# 1     [shop, pay, app, full, orders, ordering, anyth...
# 3     [why, tiktok, shop, succeed, but, instagram, s...
# 4     [tiktok, has, changed, the, way, products, are...
# 5     [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 8     [can, stop, buying, stuff, from, tiktok, shop,...
# ...                                                 ...
# 994   [you, witches, haven, been, calling, whitney, ...
# 996                     [stay, that, tiktok, shop, lol]
# 1000  [made, brand, the, month, december, ended, the...
# 1001  [the, best, part, about, tiktok, shop, the, ch...
# 1002  [slowyourprose, wtf, need, shop, through, tiktok]
#
#                                       stopwords_removed  \
# 1     [shop, pay, app, full, orders, ordering, anyth...
# 3     [tiktok, shop, succeed, instagram, shop, faile...
# 4     [tiktok, changed, way, products, marketed, for...
# 5     [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 8     [stop, buying, stuff, tiktok, shop, easily, in...
# ...                                                 ...
# 994   [witches, calling, whitney, smug, last, months...
# 996                           [stay, tiktok, shop, lol]
# 1000  [made, brand, month, december, ended, month, c...
# 1001  [best, part, tiktok, shop, chickens, coming, h...
# 1002           [slowyourprose, wtf, need, shop, tiktok]
#
#                                                pos_tags  \
# 1     [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 3     [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 4     [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
# 5     [(tiktok, NN), (shop, VBD), (new, JJ), (shopee...
# 8     [(stop, JJ), (buying, NN), (stuff, NN), (tikto...
# ...                                                 ...
# 994   [(witches, NNS), (calling, VBG), (whitney, NN)...
# 996   [(stay, NN), (tiktok, RB), (shop, NN), (lol, NN)]
# 1000  [(made, VBN), (brand, NN), (month, NN), (decem...
# 1001  [(best, JJS), (part, NN), (tiktok, NN), (shop,...
# 1002  [(slowyourprose, JJ), (wtf, NNS), (need, VBP),...
#
#                                             wordnet_pos  \
# 1     [(shop, n), (pay, n), (app, v), (full, a), (or...
# 3     [(tiktok, n), (shop, n), (succeed, v), (instag...
# 4     [(tiktok, n), (changed, v), (way, n), (product...
# 5     [(tiktok, n), (shop, v), (new, a), (shopee, a)...
# 8     [(stop, a), (buying, n), (stuff, n), (tiktok, ...
# ...                                                 ...
# 994   [(witches, n), (calling, v), (whitney, n), (sm...
# 996       [(stay, n), (tiktok, r), (shop, n), (lol, n)]
# 1000  [(made, v), (brand, n), (month, n), (december,...
# 1001  [(best, a), (part, n), (tiktok, n), (shop, n),...
# 1002  [(slowyourprose, a), (wtf, n), (need, v), (sho...
#
#                                              lemmatized label
# 1     ['shop', 'pay', 'app', 'full', 'order', 'order...   pos
# 3     ['tiktok', 'shop', 'succeed', 'instagram', 'sh...   neg
# 4     ['tiktok', 'change', 'way', 'product', 'market...   pos
# 5     ['tiktok', 'shop', 'new', 'shopee', 'app', ':'...   pos
# 8     ['stop', 'buying', 'stuff', 'tiktok', 'shop', ...   pos
# ...                                                 ...   ...
# 994   ['witch', 'call', 'whitney', 'smug', 'last', '...   neg
# 996                   ['stay', 'tiktok', 'shop', 'lol']   pos
# 1000  ['make', 'brand', 'month', 'december', 'end', ...   pos
# 1001  ['best', 'part', 'tiktok', 'shop', 'chickens',...   pos
# 1002  ['slowyourprose', 'wtf', 'need', 'shop', 'tikt...   neg
#
# [591 rows x 14 columns]

# %%
#rearrange the index

df = df.reset_index(drop=True)

# %%
df
# Out:
#                                              full_text  \
# 0    My SHOP pay app full of orders I be ordering a...
# 1    Why do TikTok Shop succeed but Instagram Shop ...
# 2    TikTok has changed the way products are market...
# 3    tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4    I can t stop buying stuff from tiktok shop I a...
# ..                                                 ...
# 586  So you witches haven t been calling Whitney sm...
# 587                     I stay on that TikTok shop lol
# 588  I made a brand $89k the month of December. I v...
# 589  The best part about TikTok Shop is the chicken...
# 590  @slowyourprose Yo wtf I need to shop through T...
#
#                                              lowercase  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3    tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand $89k the month of december. i v...
# 589  the best part about tiktok shop is the chicken...
# 590  @slowyourprose yo wtf i need to shop through t...
#
#                                            remove_link  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3    tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand $89k the month of december. i v...
# 589  the best part about tiktok shop is the chicken...
# 590  @slowyourprose yo wtf i need to shop through t...
#
#                                     mention  \
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
# ..                                      ...
# 586                                    None
# 587                                    None
# 588                                    None
# 589                                    None
# 590   yo wtf i need to shop through tiktok
#
#                                            punctuation  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3       tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand k the month of december i ve en...
# 589  the best part about tiktok shop is the chicken...
# 590  slowyourprose yo wtf i need to shop through ti...
#
#                                            expand_word  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3       tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand k the month of december i ve en...
# 589  the best part about tiktok shop is the chicken...
# 590  slowyourprose yo wtf i need to shop through ti...
#
#                                                hashtag  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3       tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand k the month of december i ve en...
# 589  the best part about tiktok shop is the chicken...
# 590  slowyourprose yo wtf i need to shop through ti...
#
#                                           remove_short  \
# 0    shop pay app full orders ordering anything see...
# 1    why tiktok shop succeed but instagram shop fai...
# 2    tiktok has changed the way products are market...
# 3             tiktok shop new shopee app :gt;gt;gt;gt;
# 4    can stop buying stuff from tiktok shop too eas...
# ..                                                 ...
# 586  you witches haven been calling whitney smug fo...
# 587                          stay that tiktok shop lol
# 588  made brand the month december ended the month ...
# 589  the best part about tiktok shop the chickens a...
# 590         slowyourprose wtf need shop through tiktok
#
#                                              tokenized  \
# 0    [shop, pay, app, full, orders, ordering, anyth...
# 1    [why, tiktok, shop, succeed, but, instagram, s...
# 2    [tiktok, has, changed, the, way, products, are...
# 3    [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 4    [can, stop, buying, stuff, from, tiktok, shop,...
# ..                                                 ...
# 586  [you, witches, haven, been, calling, whitney, ...
# 587                    [stay, that, tiktok, shop, lol]
# 588  [made, brand, the, month, december, ended, the...
# 589  [the, best, part, about, tiktok, shop, the, ch...
# 590  [slowyourprose, wtf, need, shop, through, tiktok]
#
#                                      stopwords_removed  \
# 0    [shop, pay, app, full, orders, ordering, anyth...
# 1    [tiktok, shop, succeed, instagram, shop, faile...
# 2    [tiktok, changed, way, products, marketed, for...
# 3    [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 4    [stop, buying, stuff, tiktok, shop, easily, in...
# ..                                                 ...
# 586  [witches, calling, whitney, smug, last, months...
# 587                          [stay, tiktok, shop, lol]
# 588  [made, brand, month, december, ended, month, c...
# 589  [best, part, tiktok, shop, chickens, coming, h...
# 590           [slowyourprose, wtf, need, shop, tiktok]
#
#                                               pos_tags  \
# 0    [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 1    [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 2    [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
# 3    [(tiktok, NN), (shop, VBD), (new, JJ), (shopee...
# 4    [(stop, JJ), (buying, NN), (stuff, NN), (tikto...
# ..                                                 ...
# 586  [(witches, NNS), (calling, VBG), (whitney, NN)...
# 587  [(stay, NN), (tiktok, RB), (shop, NN), (lol, NN)]
# 588  [(made, VBN), (brand, NN), (month, NN), (decem...
# 589  [(best, JJS), (part, NN), (tiktok, NN), (shop,...
# 590  [(slowyourprose, JJ), (wtf, NNS), (need, VBP),...
#
#                                            wordnet_pos  \
# 0    [(shop, n), (pay, n), (app, v), (full, a), (or...
# 1    [(tiktok, n), (shop, n), (succeed, v), (instag...
# 2    [(tiktok, n), (changed, v), (way, n), (product...
# 3    [(tiktok, n), (shop, v), (new, a), (shopee, a)...
# 4    [(stop, a), (buying, n), (stuff, n), (tiktok, ...
# ..                                                 ...
# 586  [(witches, n), (calling, v), (whitney, n), (sm...
# 587      [(stay, n), (tiktok, r), (shop, n), (lol, n)]
# 588  [(made, v), (brand, n), (month, n), (december,...
# 589  [(best, a), (part, n), (tiktok, n), (shop, n),...
# 590  [(slowyourprose, a), (wtf, n), (need, v), (sho...
#
#                                             lemmatized label
# 0    ['shop', 'pay', 'app', 'full', 'order', 'order...   pos
# 1    ['tiktok', 'shop', 'succeed', 'instagram', 'sh...   neg
# 2    ['tiktok', 'change', 'way', 'product', 'market...   pos
# 3    ['tiktok', 'shop', 'new', 'shopee', 'app', ':'...   pos
# 4    ['stop', 'buying', 'stuff', 'tiktok', 'shop', ...   pos
# ..                                                 ...   ...
# 586  ['witch', 'call', 'whitney', 'smug', 'last', '...   neg
# 587                  ['stay', 'tiktok', 'shop', 'lol']   pos
# 588  ['make', 'brand', 'month', 'december', 'end', ...   pos
# 589  ['best', 'part', 'tiktok', 'shop', 'chickens',...   pos
# 590  ['slowyourprose', 'wtf', 'need', 'shop', 'tikt...   neg
#
# [591 rows x 14 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df
# Out:
#                                              full_text  \
# 0    My SHOP pay app full of orders I be ordering a...
# 1    Why do TikTok Shop succeed but Instagram Shop ...
# 2    TikTok has changed the way products are market...
# 3    tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4    I can t stop buying stuff from tiktok shop I a...
# ..                                                 ...
# 586  So you witches haven t been calling Whitney sm...
# 587                     I stay on that TikTok shop lol
# 588  I made a brand $89k the month of December. I v...
# 589  The best part about TikTok Shop is the chicken...
# 590  @slowyourprose Yo wtf I need to shop through T...
#
#                                              lowercase  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3    tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand $89k the month of december. i v...
# 589  the best part about tiktok shop is the chicken...
# 590  @slowyourprose yo wtf i need to shop through t...
#
#                                            remove_link  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3    tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand $89k the month of december. i v...
# 589  the best part about tiktok shop is the chicken...
# 590  @slowyourprose yo wtf i need to shop through t...
#
#                                     mention  \
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
# ..                                      ...
# 586                                    None
# 587                                    None
# 588                                    None
# 589                                    None
# 590   yo wtf i need to shop through tiktok
#
#                                            punctuation  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3       tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand k the month of december i ve en...
# 589  the best part about tiktok shop is the chicken...
# 590  slowyourprose yo wtf i need to shop through ti...
#
#                                            expand_word  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3       tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand k the month of december i ve en...
# 589  the best part about tiktok shop is the chicken...
# 590  slowyourprose yo wtf i need to shop through ti...
#
#                                                hashtag  \
# 0    my shop pay app full of orders i be ordering a...
# 1    why do tiktok shop succeed but instagram shop ...
# 2    tiktok has changed the way products are market...
# 3       tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4    i can t stop buying stuff from tiktok shop i a...
# ..                                                 ...
# 586  so you witches haven t been calling whitney sm...
# 587                     i stay on that tiktok shop lol
# 588  i made a brand k the month of december i ve en...
# 589  the best part about tiktok shop is the chicken...
# 590  slowyourprose yo wtf i need to shop through ti...
#
#                                           remove_short  \
# 0    shop pay app full orders ordering anything see...
# 1    why tiktok shop succeed but instagram shop fai...
# 2    tiktok has changed the way products are market...
# 3             tiktok shop new shopee app :gt;gt;gt;gt;
# 4    can stop buying stuff from tiktok shop too eas...
# ..                                                 ...
# 586  you witches haven been calling whitney smug fo...
# 587                          stay that tiktok shop lol
# 588  made brand the month december ended the month ...
# 589  the best part about tiktok shop the chickens a...
# 590         slowyourprose wtf need shop through tiktok
#
#                                              tokenized  \
# 0    [shop, pay, app, full, orders, ordering, anyth...
# 1    [why, tiktok, shop, succeed, but, instagram, s...
# 2    [tiktok, has, changed, the, way, products, are...
# 3    [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 4    [can, stop, buying, stuff, from, tiktok, shop,...
# ..                                                 ...
# 586  [you, witches, haven, been, calling, whitney, ...
# 587                    [stay, that, tiktok, shop, lol]
# 588  [made, brand, the, month, december, ended, the...
# 589  [the, best, part, about, tiktok, shop, the, ch...
# 590  [slowyourprose, wtf, need, shop, through, tiktok]
#
#                                      stopwords_removed  \
# 0    [shop, pay, app, full, orders, ordering, anyth...
# 1    [tiktok, shop, succeed, instagram, shop, faile...
# 2    [tiktok, changed, way, products, marketed, for...
# 3    [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 4    [stop, buying, stuff, tiktok, shop, easily, in...
# ..                                                 ...
# 586  [witches, calling, whitney, smug, last, months...
# 587                          [stay, tiktok, shop, lol]
# 588  [made, brand, month, december, ended, month, c...
# 589  [best, part, tiktok, shop, chickens, coming, h...
# 590           [slowyourprose, wtf, need, shop, tiktok]
#
#                                               pos_tags  \
# 0    [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 1    [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 2    [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
# 3    [(tiktok, NN), (shop, VBD), (new, JJ), (shopee...
# 4    [(stop, JJ), (buying, NN), (stuff, NN), (tikto...
# ..                                                 ...
# 586  [(witches, NNS), (calling, VBG), (whitney, NN)...
# 587  [(stay, NN), (tiktok, RB), (shop, NN), (lol, NN)]
# 588  [(made, VBN), (brand, NN), (month, NN), (decem...
# 589  [(best, JJS), (part, NN), (tiktok, NN), (shop,...
# 590  [(slowyourprose, JJ), (wtf, NNS), (need, VBP),...
#
#                                            wordnet_pos  \
# 0    [(shop, n), (pay, n), (app, v), (full, a), (or...
# 1    [(tiktok, n), (shop, n), (succeed, v), (instag...
# 2    [(tiktok, n), (changed, v), (way, n), (product...
# 3    [(tiktok, n), (shop, v), (new, a), (shopee, a)...
# 4    [(stop, a), (buying, n), (stuff, n), (tiktok, ...
# ..                                                 ...
# 586  [(witches, n), (calling, v), (whitney, n), (sm...
# 587      [(stay, n), (tiktok, r), (shop, n), (lol, n)]
# 588  [(made, v), (brand, n), (month, n), (december,...
# 589  [(best, a), (part, n), (tiktok, n), (shop, n),...
# 590  [(slowyourprose, a), (wtf, n), (need, v), (sho...
#
#                                             lemmatized label
# 0    ['shop', 'pay', 'app', 'full', 'order', 'order...   pos
# 1    ['tiktok', 'shop', 'succeed', 'instagram', 'sh...   neg
# 2    ['tiktok', 'change', 'way', 'product', 'market...   pos
# 3    ['tiktok', 'shop', 'new', 'shopee', 'app', ':'...   pos
# 4    ['stop', 'buying', 'stuff', 'tiktok', 'shop', ...   pos
# ..                                                 ...   ...
# 586  ['witch', 'call', 'whitney', 'smug', 'last', '...   neg
# 587                  ['stay', 'tiktok', 'shop', 'lol']   pos
# 588  ['make', 'brand', 'month', 'december', 'end', ...   pos
# 589  ['best', 'part', 'tiktok', 'shop', 'chickens',...   pos
# 590  ['slowyourprose', 'wtf', 'need', 'shop', 'tikt...   neg
#
# [591 rows x 14 columns]

# %%
df.label.value_counts()
# Out:
# label
# pos    380
# neg    211
# Name: count, dtype: int64

# %%
#To check null value

df.lemmatized.isnull().value_counts()
# Out:
# lemmatized
# False    591
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (591, 14)

# %%
df.label.value_counts().plot(kind='bar',title="Sentiment Analysis")
# Out:
# <Axes: title={'center': 'Sentiment Analysis'}, xlabel='label'>

# %%
#convert label to numeric values
df['label'] = df.label.map(lambda x: int(1) if x =='pos' 
                           else int(0) if x =='neg' else np.nan)
df.head()
# Out:
#                                            full_text  \
# 0  My SHOP pay app full of orders I be ordering a...
# 1  Why do TikTok Shop succeed but Instagram Shop ...
# 2  TikTok has changed the way products are market...
# 3  tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4  I can t stop buying stuff from tiktok shop I a...
#
#                                            lowercase  \
# 0  my shop pay app full of orders i be ordering a...
# 1  why do tiktok shop succeed but instagram shop ...
# 2  tiktok has changed the way products are market...
# 3  tiktok shop is my new shopee app :&gt;&gt;&gt;...
# 4  i can t stop buying stuff from tiktok shop i a...
#
#                                          remove_link mention  \
# 0  my shop pay app full of orders i be ordering a...    None
# 1  why do tiktok shop succeed but instagram shop ...    None
# 2  tiktok has changed the way products are market...    None
# 3  tiktok shop is my new shopee app :&gt;&gt;&gt;...    None
# 4  i can t stop buying stuff from tiktok shop i a...    None
#
#                                          punctuation  \
# 0  my shop pay app full of orders i be ordering a...
# 1  why do tiktok shop succeed but instagram shop ...
# 2  tiktok has changed the way products are market...
# 3     tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4  i can t stop buying stuff from tiktok shop i a...
#
#                                          expand_word  \
# 0  my shop pay app full of orders i be ordering a...
# 1  why do tiktok shop succeed but instagram shop ...
# 2  tiktok has changed the way products are market...
# 3     tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4  i can t stop buying stuff from tiktok shop i a...
#
#                                              hashtag  \
# 0  my shop pay app full of orders i be ordering a...
# 1  why do tiktok shop succeed but instagram shop ...
# 2  tiktok has changed the way products are market...
# 3     tiktok shop is my new shopee app :gt;gt;gt;gt;
# 4  i can t stop buying stuff from tiktok shop i a...
#
#                                         remove_short  \
# 0  shop pay app full orders ordering anything see...
# 1  why tiktok shop succeed but instagram shop fai...
# 2  tiktok has changed the way products are market...
# 3           tiktok shop new shopee app :gt;gt;gt;gt;
# 4  can stop buying stuff from tiktok shop too eas...
#
#                                            tokenized  \
# 0  [shop, pay, app, full, orders, ordering, anyth...
# 1  [why, tiktok, shop, succeed, but, instagram, s...
# 2  [tiktok, has, changed, the, way, products, are...
# 3  [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 4  [can, stop, buying, stuff, from, tiktok, shop,...
#
#                                    stopwords_removed  \
# 0  [shop, pay, app, full, orders, ordering, anyth...
# 1  [tiktok, shop, succeed, instagram, shop, faile...
# 2  [tiktok, changed, way, products, marketed, for...
# 3  [tiktok, shop, new, shopee, app, :, gt, ;, gt,...
# 4  [stop, buying, stuff, tiktok, shop, easily, in...
#
#                                             pos_tags  \
# 0  [(shop, NN), (pay, NN), (app, VBP), (full, JJ)...
# 1  [(tiktok, NN), (shop, NN), (succeed, VB), (ins...
# 2  [(tiktok, NNS), (changed, VBD), (way, NN), (pr...
# 3  [(tiktok, NN), (shop, VBD), (new, JJ), (shopee...
# 4  [(stop, JJ), (buying, NN), (stuff, NN), (tikto...
#
#                                          wordnet_pos  \
# 0  [(shop, n), (pay, n), (app, v), (full, a), (or...
# 1  [(tiktok, n), (shop, n), (succeed, v), (instag...
# 2  [(tiktok, n), (changed, v), (way, n), (product...
# 3  [(tiktok, n), (shop, v), (new, a), (shopee, a)...
# 4  [(stop, a), (buying, n), (stuff, n), (tiktok, ...
#
#                                           lemmatized  label
# 0  ['shop', 'pay', 'app', 'full', 'order', 'order...      1
# 1  ['tiktok', 'shop', 'succeed', 'instagram', 'sh...      0
# 2  ['tiktok', 'change', 'way', 'product', 'market...      1
# 3  ['tiktok', 'shop', 'new', 'shopee', 'app', ':'...      1
# 4  ['stop', 'buying', 'stuff', 'tiktok', 'shop', ...      1

# %%
df= df[['lemmatized','label']]
df.head()
# Out:
#                                           lemmatized  label
# 0  ['shop', 'pay', 'app', 'full', 'order', 'order...      1
# 1  ['tiktok', 'shop', 'succeed', 'instagram', 'sh...      0
# 2  ['tiktok', 'change', 'way', 'product', 'market...      1
# 3  ['tiktok', 'shop', 'new', 'shopee', 'app', ':'...      1
# 4  ['stop', 'buying', 'stuff', 'tiktok', 'shop', ...      1

# %%
from sklearn.model_selection import train_test_split
lemmatize = df['lemmatized'].values
labels = df['label'].values
lemmatize_train, lemmatize_test, labels_train, labels_test = train_test_split(lemmatize, labels)

print(lemmatize_train.shape)
print(lemmatize_test.shape)
print(labels_train.shape)
print(labels_test.shape)
# Out:
# (443,)
# (148,)
# (443,)
# (148,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
lemmatizer = WordNetLemmatizer()
corpus=[]
messages = df.lemmatized.tolist()

for i in range(0, len(messages)):
    message = re.sub('[^a-zA-Z]', ' ', str(messages[i]))
    message = message.lower()
    message = message.split()
    message = [lemmatizer.lemmatize(word) for word in message if not word in stopwords.words('english')]
    message = ' '.join(message)
    corpus.append(message)

# %%
vectorizer = TfidfVectorizer(min_df = 5,
                              max_df = 0.8,
                              sublinear_tf = True,
                              use_idf = True)

# %%
tfidf = vectorizer.fit_transform(df.lemmatized)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
vectorizer = vectorizer.fit(corpus)
X = vectorizer.transform(corpus).toarray()

X.shape
# Out:
# (591, 2309)

# %%
y = df['label'].replace(0, -1)

# %%
from sklearn.manifold import TSNE
import seaborn as sns
labels = y.to_list()
tsne_results = TSNE(n_components=2,init='random',random_state=0, perplexity=40).fit_transform(X)
plt.figure(figsize=(20,10))
palette = sns.hls_palette(2, l=.3, s=.9)
sns.scatterplot(
    x=tsne_results[:,0], y=tsne_results[:,1],
    hue=labels,
    palette= palette,
    legend="full",
    alpha=0.3
)
plt.show()

# %%
# Split dataset to Testing and Training

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

#70/30
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.30, random_state = 0)

# %%
X_train.shape
# Out:
# (413, 2309)

# %%
X_test.shape
# Out:
# (178, 2309)

# %% [markdown]
# # SVM Algorithm

# %%
from collections import Counter

# %%
print("Before SMOTE :" , Counter(y_train))
# Out:
# Before SMOTE : Counter({1: 263, -1: 150})

# %%
sm = SMOTE(random_state=2, sampling_strategy='auto', k_neighbors=5)
X_train_balanced, y_train_balanced = sm.fit_resample(X_train, y_train)

# %%
print("After SMOTE :" , Counter(y_train))
# Out:
# After SMOTE : Counter({1: 263, -1: 150})

# %%
#To create kernel Matrix
k_value = np.array(X_train @ X_train.T + np.identity(len(y_train))*1e-12)
k_value
# Out:
# array([[1.        , 0.06510308, 0.01621964, ..., 0.01116388, 0.01476565,
#         0.01404713],
#        [0.06510308, 1.        , 0.01207918, ..., 0.00831403, 0.01099636,
#         0.01046125],
#        [0.01621964, 0.01207918, 1.        , ..., 0.01326927, 0.01755029,
#         0.09820446],
#        ...,
#        [0.01116388, 0.00831403, 0.01326927, ..., 1.        , 0.01207976,
#         0.01149193],
#        [0.01476565, 0.01099636, 0.01755029, ..., 0.01207976, 1.        ,
#         0.11726512],
#        [0.01404713, 0.01046125, 0.09820446, ..., 0.01149193, 0.11726512,
#         1.        ]])

# %%
#To set up and minimize the dual function
#Create optimization variables
alpha = cp.Variable(shape = y_train.shape)

#To simplify notation
beta = cp.multiply(alpha, y_train)

K = cp.Parameter(shape = k_value.shape, PSD = True, value = k_value)

#Objective function
obj = .5 * cp.quad_form(beta, K) - np.ones(alpha.shape).T @ alpha

class_weights = dict(zip(np.unique(y_train), 
                        [1 / (np.sum(y_train == c) / len(y_train)) for c in np.unique(y_train)]))

#Constraints
const = [np.array(y_train.T) @ alpha == 0,
         -alpha <= np.zeros(alpha.shape),
         alpha <= [10 * class_weights[y] for y in y_train]]

prob = cp.Problem(cp.Minimize(obj), const)

# %%
result = prob.solve()

# %%
np.linalg.cholesky(k_value) #to check PSD
# Out:
# array([[ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 6.51030773e-02,  9.97878544e-01,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.62196441e-02,  1.10466665e-02,  9.99807429e-01, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 1.11638824e-02,  7.60335335e-03,  1.30067079e-02, ...,
#          1.22483330e-06,  0.00000000e+00,  0.00000000e+00],
#        [ 1.47656520e-02,  1.00564003e-02,  1.72030228e-02, ...,
#          2.28963325e-09,  6.27903840e-01,  0.00000000e+00],
#        [ 1.40471256e-02,  9.56703555e-03,  9.78897853e-02, ...,
#         -2.57428699e-09,  8.95222842e-03,  7.02721257e-01]])

# %%
w = np.multiply(y_train, alpha.value).T @ X_train

# %%
S = (alpha.value > 1e-4).flatten()
b = y_train[S] - X_train[S] @ w
# b = b[0]
b = np.mean(b)

# %%
def classify(x):
    result = w @ x + b
    return np.sign(result)

# %%
import numpy as np
correct = 0
incorrect = 0
predictions = []
for i in X_test:
    my_svm = classify(i)
    
    predictions = np.append(predictions, my_svm)
    
    predictions = np.array(predictions)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.80      0.64      0.71        61
#            1       0.83      0.91      0.87       117
#
#     accuracy                           0.82       178
#    macro avg       0.81      0.78      0.79       178
# weighted avg       0.82      0.82      0.81       178

# %%
accuracy_score(y_test, predictions)
print('Model accuracy score with linear kernel and C=100.0 : {0:0.4f}'. format(accuracy_score(y_test, predictions)*100))
# Out:
# Model accuracy score with linear kernel and C=100.0 : 82.0225

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
fpr, tpr, threshold = metrics.roc_curve(y_test, predictions)
roc_auc = metrics.auc(fpr, tpr)

# %%
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %% [markdown]
# # WORDCLOUD

# %%
# import required libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# read data into a dataframe
df = pd.read_csv(r'F:\Uni Stuff\BUSINESS CASE_GROUP PROJECT\Preprocessed_Data')

# combine all text into a single string
text = ' '.join(df['full_text'].tolist())

# create a WordCloud object
wordcloud = WordCloud(width=800, height=800,
                      background_color='black',
                      stopwords=STOPWORDS,
                      min_font_size=10).generate(text)

# plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

# show the plot
plt.show()
